# %% [markdown]
# ### **Data Ingestion**

# %%
### document datastructure
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="this is the main text content I am using to create RAG",
    metadata ={
        "source":"example.txt",
        "pages":1,
        "author": "Keira",
        "date created":"2026-02-06"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Keira', 'date created': '2026-02-06'}, page_content='this is the main text content I am using to create RAG')

# %%
###creating a simple txt file
import os

os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
### TextLoader
from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16332\2087070391.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", ## Pattern to match files  
    loader_cls= TextLoader, ##loader class to use
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False

)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", ## Pattern to match files  
    loader_cls= PyMuPDFLoader, ##loader class to use
    show_progress=False

)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'Skia/PDF m143', 'creator': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/143.0.0.0 Safari/537.36', 'creationdate': 'D:20260103151550', 'source': "..\\data\\pdf\\Valerie Onsongo Resume DS '26.pdf", 'file_path': "..\\data\\pdf\\Valerie Onsongo Resume DS '26.pdf", 'total_pages': 2, 'format': 'PDF 1.4', 'title': 'Valerie DS', 'author': 'Valerie DS', 'subject': '', 'keywords': 'Large Language Models & Generative AI, Data Analysis & Visualization: Skilled in Qlik Sense, Tableau, Power BI, Seaborn and Matplotlib., Big Data Technologies: Proficient in PySpark, Databricks, Scala and Apache Spark, Deep learning solutions: Skilled in Natural Language Processing (NLP), anomaly detection and image recognition, SQL Database Management: Skilled in Oracle, MySQL, and PostgreSQL., Python Programming, Automation & Web Scraping: Streamlining workflows and extracting data efficiently., Machine Learning & Deep Learning: Proficiency in TensorFlow, Keras and scikit-learn; experienced with CNNs, neural networks, Cloud Platforms: Experience with AWS services (S3, Glue, QuickSight, Athena, Sagemaker, Fraud detector)', 'moddate': 'D:20260103151550', 'trapped': '', 'modDate': 'D:20260103151550', 'creationDate': 'D:20260103151550', 'page': 0}, page_content="VALERIE ONSONGO\nvalerieonsongo@gmail.com\n+254791547840\nin/valerie-m-onsongo-37552918a\ngithub.com/valeriemoks\nSUMMARY\nResults-driven professional with a strong passion for artificial intelligence, automation and data analytics. Adept at applying advanced machine\nlearning techniques, data engineering, and data analysis to streamline processes and generate actionable insights. Proficient in Python, SQL,\nand Big Data technologies, with extensive experience in data analysis and visualization tools. Committed to delivering innovative solutions that\nalign with organizational goals and enhance data-driven decision-making in data science, data analysis and data engineering.\nEXPERIENCE\nData Scientist\nSAFARICOM PLC\nJanuary 2025 - Present Nairobi\n,\nDeveloped and deployed a microservice for automated data extraction from PDFs to JSON, and conducted advanced experimentation with\nLLamaParse, OCR, and GENAI to handle non-selectable and low-quality documents.\n•\nCurrently leading end-to-end data analytics initiatives for a utility-sector partner, delivering actionable insights by analyzing energy\nconsumption patterns, customer behaviors, and segmentation to enable early detection of anomalies and inefficiencies.\n•\nApplied machine learning, anomaly detection, and time-series forecasting techniques to identify abnormal usage trends, support fraud\ndetection, and strengthen compliance monitoring.\n•\nDesigned dashboards and rule-based alerting systems for real-time anomaly monitoring, significantly improving operational decision-\nmaking, compliance oversight, and exception handling.\n•\nCollaborated cross-functionally to implement data-driven strategies that enhance monitoring, reporting, and risk assessment practices.\n•\nData Scientist\nProspect 33| Global Data Lab\nJune 2024 - September 2024 New York\n,\nAnomaly Detection Algorithms: Implemented advanced anomaly detection algorithms from the PyOD library on ADbench datasets,\nenhancing outlier detection capabilities in financial datasets.\n•\nData Pipeline Development: Developed a Python-based data pipeline to ensure continuous data flow, optimizing the model building and\nevaluation processes.\n•\nFraud Detection Analysis: Conducted in-depth analysis of credit card fraud detection, created robust anomaly detection models, and explored\nexplainability techniques such as SHAP for improved model interpretability.\n•\nProduced detailed weekly progress reports and delivered an end-of-project presentation of findings to stakeholders implementing anomaly\ndetection in financial services.\n•\nData Science and Automations Intern\nSAFARICOM  PLC\nNovember 2023 - May 2024 Nairobi\n,\nC ...
#  Document(metadata={'producer': 'Skia/PDF m143', 'creator': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/143.0.0.0 Safari/537.36', 'creationdate': 'D:20260103151550', 'source': "..\\data\\pdf\\Valerie Onsongo Resume DS '26.pdf", 'file_path': "..\\data\\pdf\\Valerie Onsongo Resume DS '26.pdf", 'total_pages': 2, 'format': 'PDF 1.4', 'title': 'Valerie DS', 'author': 'Valerie DS', 'subject': '', 'keywords': 'Large Language Models & Generative AI, Data Analysis & Visualization: Skilled in Qlik Sense, Tableau, Power BI, Seaborn and Matplotlib., Big Data Technologies: Proficient in PySpark, Databricks, Scala and Apache Spark, Deep learning solutions: Skilled in Natural Language Processing (NLP), anomaly detection and image recognition, SQL Database Management: Skilled in Oracle, MySQL, and PostgreSQL., Python Programming, Automation & Web Scraping: Streamlining workflows and extracting data efficiently., Machine Learning & Deep Learning: Proficiency in TensorFlow, Keras and scikit-learn; experienced with CNNs, neural networks, Cloud Platforms: Experience with AWS services (S3, Glue, QuickSight, Athena, Sagemaker, Fraud detector)', 'moddate': 'D:20260103151550', 'trapped': '', 'modDate': 'D:20260103151550', 'creationDate': 'D:20260103151550', 'page': 1}, page_content='calculation and historical trend analysis. Future plans include portfolio analysis with ML and real-time stock alerts.\nSpotify Data Engineering Project\nDeveloped an end-to-end data engineering solution using AWS services, including S3, Glue, and QuickSight. \n•\nApplied data modeling principles to design and optimize data schemas, ensuring efficient data storage and retrieval. \n•\nSet up S3 buckets for staging and warehousing, built ETL pipelines with AWS Glue, and managed schema with Glue Crawler and Data Catalog. \n•\nDocumented and optimized data architecture through detailed diagrams, enhancing the overall data pipeline structure and performance.\n•\nCredit card fraud detection system\nDeveloped a credit card fraud detection system with 95% accuracy through deep data analysis and advanced algorithms like Random Forest,\nXGBoost, and LightGBM, leveraging rigorous K-fold cross-validation for optimal model selection.\n•\nDeployed the system using two methods: a Flask-based web application for usability and a scalable solution using Amazon SageMaker.\n•\nExperimented with Amazon Fraud Detector to explore enhanced fraud detection capabilities and improve system robustness.\n•\nCustomer Churn Prediction Model\nEngineered a customer churn prediction model with 90% accuracy, leveraging advanced machine learning techniques and in-depth data\nanalysis.\n•\nImproved model performance through feature engineering and hyperparameter tuning, deriving actionable insights for customer retention\nstrategies.\n•\nDeployed the model using Amazon SageMaker, ensuring scalability and integration into production environments.\n•\nLoan Default Prediction Model\nEngineered a loan default prediction model using Random Forest, XGBoost, and deep neural networks, achieving 85% accuracy.\n•\nPerformed hyperparameter tuning using GridSearchCV to optimize model performance and achieve precise predictions.\n•\nImplemented stacking techniques to combine models into a powerful hybrid system, further enhancing predictive accuracy.\n•\nEDUCATION\nBACHELOR OF SCIENCE IN ELECTRICAL AND TELECOMMUNICATION ENGINEERING\nMULTIMEDIA UNIVERSITY OF KENYA\nAPPLIED DATA SCIENCE LAB| WORLDQUANT UNIVERSITY\nCompleted 8 diverse data science projects, solving real-world problems and showcasing proficiency in varied analytical techniques.\n•\nNANODEGREE- AI PROGRAMMING WITH PYTHON   | UDACITY\nCompleted 8 diverse data science projects, solving real-world problems and showcasing proficiency in varied analytical techniques.\n•\nSIMPLILEARN - APACHE SPARK\nCompleted a comprehensive course on Apache Spark, covering fundamental concepts and practical applications, including data pr ...

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
